# %%
import torch
from torchvision.transforms import transforms
from torch.autograd import Variable
import os
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np
model_conv1=torch.load("HC#3266animal_model.pth",map_location=lambda storage,loc:storage)
classes_names1=model_conv1['class_names']
model_conv2=model_conv1['model']

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
def predict(model,image):
            model.eval()
            img_loader = transforms.Compose([ 
        transforms.CenterCrop(224), 
        transforms.ToTensor(),
             transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
            desired_size=224
            im = Image.open(image)
            im1=im.resize((224,224),Image.ANTIALIAS)
            new_im1 = Image.new("RGB", (desired_size, desired_size))
            new_im1.paste(im1, (0,0))  
            image_tensor1 = img_loader(new_im1).float()
            image1 = image_tensor1.unsqueeze(0).float()
            outputs = model(image1)
            _, preds = torch.max(outputs, 1)
            ax = plt.subplot(111)
            ax.axis('off')
            ax.set_title('predicted: {}'.format(classes_names1[preds[0]]))
            imshow(image1.cpu().data[0])

# %%
predict(model_conv2,"1.jpg")

# %%
predict(model_conv2,"2.jpg")

# %%
predict(model_conv2,"3.png")

# %%
predict(model_conv2,"4.jpg")

# %%
predict(model_conv2,"5.jpg")

# %%
predict(model_conv2,"6.jpg")

# %%
predict(model_conv2,"7.jpg")

# %%
predict(model_conv2,"8.jpg")

# %%
predict(model_conv2,"9.jpg")

# %%
predict(model_conv2,"10.jpg")

# %%
model_conv1=torch.load("HC#3266habitat_model.pth",map_location=lambda storage,loc:storage)
classes_names1=model_conv1['class_names']
model_conv2=model_conv1['model']

# %%
predict(model_conv2,"11.jpg")

# %%
predict(model_conv2,"12.jpg")

# %%
predict(model_conv2,"13.jpg")

# %%
predict(model_conv2,"14.jpg")

# %%
predict(model_conv2,"15.jpg")
